# %% [markdown]
# Work in Progress. Will be updated by Friday. Ricky Oropeza
#
# This file cleans the Airbnb data.
# 1. Grabs only LA listings from the raw data
#
# Can be used for other cities

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_2023 = pd.read_csv('AB_US_2023.csv')
df_2020 = pd.read_csv('AB_US_2020.csv')
# Out:
# C:\Users\Ricky\AppData\Local\Temp\ipykernel_32804\1394389679.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2023 = pd.read_csv('AB_US_2023.csv')
# C:\Users\Ricky\AppData\Local\Temp\ipykernel_32804\1394389679.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2020 = pd.read_csv('AB_US_2020.csv')

# %%
df_2023.head()
# Out:
#      id                                               name  host_id  \
# 0   958              Bright, Modern Garden Unit - 1BR/1BTH     1169
# 1  5858                                 Creative Sanctuary     8904
# 2  8142  Friendly Room Apt. Style -UCSF/USF - San Franc...    21994
# 3  8339                    Historic Alamo Square Victorian    24215
# 4  8739                Mission Sunshine, with Private Bath     7149
#
#           host_name neighbourhood_group     neighbourhood  latitude  \
# 0             Holly                 NaN  Western Addition  37.77028
# 1  Philip And Tania                 NaN    Bernal Heights  37.74474
# 2             Aaron                 NaN    Haight Ashbury  37.76555
# 3              Rosy                 NaN  Western Addition  37.77564
# 4      Ivan & Wendy                 NaN           Mission  37.76030
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
df_2023_LA = df_2023[df_2023['city'] == 'Los Angeles']
df_2020_LA = df_2020[df_2020['city'] == 'Los Angeles']

# %%
df_2023_LA.to_csv('AB_LosAngeles_2023.csv')
df_2020_LA.to_csv('AB_LosAngeles_2020.csv')
# Out:
#                        id                                               name  \
# 24260  770565020594037590                    Phillips Ranch room with a view
# 24261  777451666060243581                               Family oriented home
# 24262  698097753730921190                                             方便易居驿站
# 24263            13063118  TERRANEA OCEANFRNT 1BR CASITA -203 RSRT AMENIT...
# 24264            39337076          Brand New Duplex Near World Cruise Center
#
#          host_id host_name   neighbourhood_group        neighbourhood  \
# 24260   30603612  Yamileth          Other Cities               Pomona
# 24261  490709958      Dana  Unincorporated Areas      Castaic Canyons
# 24262  444692513     Hanna          Other Cities               Pomona
# 24263   41736985      Beth          Other Cities  Rancho Palos Verdes
# 24264  208375458       Jae          Other Cities  Rancho Palos Verdes
#
#         latitude   longitude     room_type  price  minimum_nights  \
# ...
